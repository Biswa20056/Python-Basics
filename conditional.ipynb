# %% [markdown]
# Q1. Check a number is positive, negative or zero

# %%
n = -12
if (n>=0):
    if (n==0):
        print(f"{n} is zero.")
    else:
        print(f"{n} is a positive number.")
else:
    print(f"{n} is a negative number.")
# Out:
# -12 is a negative number.

# %% [markdown]
# Q2. CHECK A NUMBER IS EVEN OR ODD

# %%
n = 12
if(n%2==0):
    print(f"{n} is an even number.")
else:
    print(f"{n} is an odd number.")
# Out:
# 12 is an even number.

# %% [markdown]
# Q3. Find the largest of 2 number.

# %%
n1 = 12
n2 = 23
if (n1>n2):
    print(f"{n1} is the highest.")
else:
    print(f"{n2} is the highest.")
# Out:
# 23 is the highest.

# %% [markdown]
# Q4. Find the smallest of two number

# %%
n1 = 23
n2 = 45
if (n1<n2):
    print(f"{n1} is the smallest.")
else:
    print(f"{n2} is the smallest.")
# Out:
# 23 is the smallest.

# %% [markdown]
# Q5. Check whether a person is eliogible or not.

# %%
age = int(input("Enter the age:"))
if (age>=18):
    print("Eligible to vote.")
else:
    print("Not eligible to vote.")
# Out:
# Eligible to vote.

# %% [markdown]
# Q6. Check wether a year is a leap year or not.

# %%
year = int(input("Enter the year:"))
if (year%400==0) or (year%4==0 and year%100!=0):
    print(f"{year} is a leap year.")
else:
    print(f"{year} is not a leap year.")
# Out:
# 2022 is not a leap year.

# %% [markdown]
# Q7. Check wether a character is a vowel or not.

# %%
ch = input("Enter the character.")
if ch.lower() in 'aeiou':
    print("Vowel.")
else:
    print("Consonant.")
# Out:
# Consonant.

# %% [markdown]
# Q7. Check wether a number is divisible by both 3 and 5.

# %%
n = int(input("Enter the number:"))
if (n%3==0 and n%5==0):
    print(f"{n} is divisible by both 3 and 5.")
else:
    print(f"{n} is not divisible by both.")
# Out:
# 9 is not divisible by both.

# %% [markdown]
# Q8. Check wether a number is multiple of 7 or not.

# %%
n = int(input("Enter the number:"))
if (n%7==0):
    print(f"{n} is a multiple of 7.")
else:
    print(f"{n} is not a multiple of 7.")
# Out:
# 23 is not a multiple of 7.

# %% [markdown]
# Q8. Check wether a character is uppercase or lower case.

# %%
ch = input("Enter the character:")
if ch.isupper():
    print(f"{ch} is an uppercase.")
else:
    print(f"{ch} is a lowercase")
# Out:
# QW is an uppercase.

# %% [markdown]
# Q9. Find the largets of 3 numbers.

# %%
n1 = int(input("Enter the 1st number:"))
n2 = int(input("Enter the 2nd number:"))
n3 = int(input("Enter the 3rd number:"))
if (n1==n2==n3):
    print("All the numbers are same.")
else:
    if (n1>n2):
        if (n1>n3):
            print(f"{n1} is the largest number.")
        else:
            print(f"{n3} is the largest number.")
    else:
        if (n2>n3):
            print(f"{n2} is the largest number.")
        else:
            print(f"{n3} is the largest number.")
# Out:
# 100 is the largest number.

# %% [markdown]
# Q10. find the largets number by elif condition

# %%
n1 = int(input("Enter the 1st number:"))
n2 = int(input("Enter the 2nd number:"))
n3 = int(input("Enter the 3rd number:"))
if (n1==n2==n3):
    print("All the numbers are same.")
elif n1>=n2 and n1>=n3:
    print(f"{n1} is the largest number.")
elif n2>=n1 and n2>=n3:
    print(f"{n2} is the largest number.")
else:
    print(f"{n3} is the largest number.")
# Out:
# 56 is the largest number.

# %% [markdown]
# Q11. Check weather the three angles of a trinagle form a valid triangle or not.

# %%
a1  = int(input("Enter the 1st angle:"))
a2 = int(input("Enter the 2nd angle:"))
a3 = int(input("Enter the 3rd angle:"))
if (a1+a2+a3)==180:
    print("This forms a valid triangle.")
else:
    print("This is not a valid triangle!")
# Out:
# This forms a valid triangle.

# %% [markdown]
# Q12. Print grade based marks.

# %%
marks = int(input("Enter the marks:"))
if (marks>=90):
    print('Grade A')
elif (marks>=80):
    print("Grade B")
elif (marks>=70):
    print("Grade C")
elif (marks>=60):
    print("Grade D")
else:
    print("Grade F")
# Out:
# Grade C

# %% [markdown]
# Q13. Check a number is 2 digit, 3digit or ,4digit

# %%
num = abs(int(input("Enter a number:")))
if (10<=num<=99):
    print(f"{num} is a 2-digit number.")
elif (100<=num<=999):
    print(f"{num} is a 3-digit number.")
elif (1000<=num<=9999):
    print(f"{num} is a 4-digit number.")
else:
    print(f"{num} is not a 2-digit,3-digit,4-digit number.")
# Out:
# 23456 is not a 2-digit,3-digit,4-digit number.

# %% [markdown]
# Q14. Check wether a character is alphabet , digit or special character.

# %%
ch = input("Enter the character:")
if ch.isalpha():
    print(f"{ch} is a alphabet.")
elif ch.isdigit():
    print(f"{ch} is a digit.")
else:
    print(f"{ch} is a special character.")
# Out:
# @ is a special character.

# %% [markdown]
# Q15. Calculate discount.

# %%
amount = float(input("Enter the amount:"))
if (amount>=5000):
    discount = amount * .20
elif (amount>=2000):
    discount = amount * .10
else:
    discount = 0
print("Discount:", discount)
print("Total Paid amount:", amount-discount)
# Out:
# Discount: 1000.0
# Total Paid amount: 4000.0

# %% [markdown]
# Q16. Check a Student is passed or fail.

# %%
m1 = float(input("Enter marks for 1st subject:"))
m2 = float(input("Enter marks for 2nd subject:"))
m3 = float(input("enter marks for 3rd subject:"))
if (m1>35 and m2>35 and m3>35):
    print("Pass.")
else:
    print("Fail.")
# Out:
# Fail.

# %% [markdown]
# Q17. Chec wether a number lies between 100 and 999.

# %%
n = int(input("Enter the number:"))
if (100<=n<=999):
    print(print(f"{n} lies between {100} and {999}."))
else:
    print(f"{n} lies between {100} and {999}.")
# Out:
# 789 lies between 100 and 999.
# None

# %% [markdown]
# Q18. Find the middle number among three number.

# %%
n1 = int(input("Enter the 1st number:"))
n2 = int(input("Enter the 2nd number:"))
n3 = int(input("Enter the 3rd number:"))
if (n1>n2 and n1<n3) or (n1>n3 and n1<n2):
    print(f"{n1} is the middle number.")
elif (n2>n1 and n2<n3) or (n2>n3 and n2<n1):
    print(f"{n2} is the middle number.")
else:
    print(f"{n3} is the middle number.")
# Out:
# 10 is the middle number.

# %% [markdown]
# Q19. Check a number is divisible by both 2 and 3 or neither.

# %%
num = int(input("Enter the number:"))
if (num%2==0 and num%3==0):
    print(f"{num} is divisible by both 2 and 3.")
elif (num%2==0):
    print(f"{num} is divisible by 2.")
elif (num%3==0):
    print(f"{num} is divisible by 3.")
else:
    print(f"{num} is neither divisible by 2 or 3.")
# Out:
# 11 is neither divisible by 2 or 3.
