# %% [markdown]
# In this folder All the built-in functions will be done.

# %% [markdown]
# Input function:

# %%
s = input('Enter name:')
print(s)
print(type(s))
d = int(input('Enter the number:'))
print(d)
print(type(d))
f = float(input("Enter the decimal number:"))
print(f)
print(type(f))
# Out:
# Biswa
# <class 'str'>
# 12
# <class 'int'>
# 12.9
# <class 'float'>

# %% [markdown]
# Input function can not get all the data based on user requirements so eval function used.

# %% [markdown]
# eval function:

# %%
s = eval('5')
print(s)
print(type(s))
d = eval('[1,2,3,4]')
print(d)
print(type(d))
st = eval('{1,2,3,4}')
print(st)
print(type(st))
t = eval('(1,2,"A",True)')
print(t)
print(type(t))
# Out:
# 5
# <class 'int'>
# [1, 2, 3, 4]
# <class 'list'>
# {1, 2, 3, 4}
# <class 'set'>
# (1, 2, 'A', True)
# <class 'tuple'>

# %%
s = input('Enter the number:')
print(s)
print(type(s))

# %%
s = eval(input('Enter the number:'))
print(s)
print(type(s))
# Out:
# 12
# <class 'int'>

# %% [markdown]
# Built-in functions

# %% [markdown]
# String-Built-in Functions:

# %% [markdown]
# 1. count():It returns the occurrences of given substring and it returns integer.

# %% [markdown]
# Syntax1: variablename.count(substring)

# %%
s = 'abcdea'
print(s.count('a'))# it will give the frequency of substring in the main string
print(s.count('j'))# if substring is not present it will simply return 0
print(s.count('ab'))
print(s.count(''))# it will return len+1 bcoz after and before substring there is an empty string
# Out:
# 2
# 0
# 1
# 7

# %% [markdown]
# Syntax2: variablename.count(substring,starting position)

# %%
s = 'abcdabcded'
print(s.count('a',0))# from 0th index to last how many a is there
print(s.count('a',1))
print(s.count('d',-3))# no matter what but the operation will be performed from left to right direction
print(s.count('ab',0))
print(s.count('ab',1))
print(s.count('cd',2))
print(s.count('cd',3))
print(s.count('cd',4))
print(s.count('h',2))
# Out:
# 2
# 1
# 2
# 2
# 1
# 2
# 1
# 1
# 0

# %% [markdown]
# Syntax3: variablename.count(substring, starting position, ending position)

# %%
s = 'abcdbcdabc'
print(s.count('a',2,7))# this syntax will not include the ending position
print(s.count('a',2,8))
print(s.count('ab',0,3))
print(s.count('c',-5,0))
print(s.count('c',-5,-3))
print(s.count('c',-5,8))
print(s.count('k',0,len(s)))
# Out:
# 0
# 1
# 1
# 0
# 1
# 1
# 0

# %% [markdown]
# 2. Split Function:

# %% [markdown]
# 1. split function breaks the string based on given substring
# 2. if no argument is given space is default substring
# 3. split function returns list of substrings.

# %% [markdown]
# Syntax1: variablename.split(substring)

# %%
s = 'Hello bye world'
print(s.split('e'))# the number of times split happens more than one will be output in list format
print(s.split())
print(s.split('l'))
print(s.split('ll'))
print(s.split('k'))
# Out:
# ['H', 'llo by', ' world']
# ['Hello', 'bye', 'world']
# ['He', '', 'o bye wor', 'd']
# ['He', 'o bye world']
# ['Hello bye world']

# %% [markdown]
# Syntax2: variablename.split()

# %%
s = 'hello bye world'
print(s.split())
print(s.split(' '))
# Out:
# ['hello', 'bye', 'world']
# ['hello', 'bye', 'world']

# %% [markdown]
# Syntax3: variablename.split(substring,count)
#  Here count refers to how many times you want to split

# %% [markdown]
# Note: After one split and before one split all the characters should be there if there is no substring then empty string will takes place

# %%
s = 'abcbacabc'
print(s.split('b'))
print(s.split('b',1))
print(s.split('b',2))
print(s.split('b',10))# the max number of b will be there as many times split will happend and rest will be ignored
# Out:
# ['a', 'c', 'aca', 'c']
# ['a', 'cbacabc']
# ['a', 'c', 'acabc']
# ['a', 'c', 'aca', 'c']

# %% [markdown]
# 3. index function:

# %% [markdown]
# 1. Index function return the index position of the first occurence of that substring
# 2. if given subnstring is not present then index function throws valueError
# 3. index function returns integer

# %% [markdown]
# Syntax1: variablename.index(substring)

# %%
s = 'abcdabcdabcd'
print(s.index('a'))
print(s.index('d'))
# it will raise value error print(s.index('y'))
# print(s.index()) atleast pne argument should be inside index function
# Out:
# 0
# 3

# %% [markdown]
# Syntax2: variablename.index(substring, starting position)

# %%
s = 'abcdabcdabcd'
print(s.index('c',2))
print(s.index('c',3))
print(s.index('c',7))
print(s.index('b',-9))
# print(s.index('c',11) this will give substring out of range error
# Out:
# 2
# 6
# 10
# 5

# %% [markdown]
# Syntax3: variablename.index(substring,starting position, ending position)

# %%
s = 'abcabcabc'
print(s.index('c',1,11))
print(s.index('c',-7,-3))
#print(s.index('c',-7,1)) this will also raise error that substring not found
print(s.index('c',-8,10))
# Out:
# 2
# 2
# 2

# %% [markdown]
# to get the second occurence of any substring

# %% [markdown]
# Syntax: varname.index(substring, varname.index(substring)+1)

# %%
s = 'abcabcabc'
print(s.index('a'))# 1st occurrence
print(s.index('a', s.index('a')+1))# 2nd occurrence
print(s.index('a', s.index('a', s.index('a')+1)+1))# 3rd occurrence
# Out:
# 0
# 3
# 6
# 6

# %% [markdown]
# 4. find function:

# %% [markdown]
# 1. Find function return the index position of first occurence of substring
# 2. if the given substring is not present it simply returns -1
# 3. find function returns integer
# 4. all the 3 syntaxes applicable for index function also be for find function

# %% [markdown]
# Syntax1: varname.find(substring)

# %%
s = 'abcabcabc'
print(s.find('a'))
print(s.find('b'))
print(s.find('k'))# this substr is not present so it returned -1
# Out:
# 0
# 1
# -1

# %% [markdown]
# Syntax2: varname.find(substring, starting pos)

# %%
s = 'abcabcabc'
print(s.find('b',1))
print(s.find('c',-4))
print(s.find('p',4))
print(s.find('a',1))
# Out:
# 1
# 5
# -1
# 3

# %% [markdown]
# Syntax3: varname.find(substring, starting pos, ending pos)

# %%
s = 'abcabcabc'
print(s.find('a',0,2))
print(s.find('a',1,3))
print(s.find('b',-3,6))
print(s.find('b',-3,len(s)))
# Out:
# 0
# -1
# -1
# 7

# %% [markdown]
# 5. rindex function:

# %% [markdown]
# 1. rindex function returns the last occurrence of the substring in agive string
# 2. in every searching will perform from left to right of the main string
# 3. if the substring is not present in that main string rindex will throw error
# 4. rindex returns integer

# %% [markdown]
# Syntax1: varname.rindex(substring)

# %%
s = 'abcdabcdabcd'
print(s.rindex('a'))
print(s.rindex('d'))
print(s.rindex('c'))
# print(s.rindex('p')) this will raise value error
# Out:
# 8
# 11
# 10

# %% [markdown]
# syntax2: varname(substring, starting pos)

# %%
s = 'abcdabcdabcd'
print(s.rindex('b',1))
print(s.rindex('a',1))
print(s.rindex('d',10))
# Out:
# 9
# 8
# 11

# %% [markdown]
# syntax3: varname.rindex(substring, starting pos, ending position)

# %%
s = 'abcdabcdabcd'
# this will raise error bcoz in that range no substring 'a' is present print(s.rindex('a',1,4))
print(s.rindex('a',0,4))
print(s.rindex('b',1,8))
# Out:
# 0
# 5

# %% [markdown]
# To get last but one occurrence means the second occurrence from last direction of a substring by rindex

# %%
s = 'abcdabcdabcd'
print(s.rindex('a'))# last occurence
print(s.rindex('a', 0, s.rindex('a')))# last but one
print(s.rindex('b'))
print(s.rindex('b',0,s.rindex('b')))# last but one index
print(s.rindex('b', 0, s.rindex('b',0,s.rindex('b'))))# last but 2 index
# Out:
# 8
# 4
# 9
# 5
# 1

# %% [markdown]
# 6. rfind function:

# %% [markdown]
# 1. rfind functions returns the last occcurence of a subtring
# 2. if the given substring is not present it will simply return -1
# 3. r find function returns integer

# %% [markdown]
# Syntax1: varname.rfind(substring)

# %%
s = 'abcdabcdabcd'
print(s.rfind('a'))
print(s.rfind('d'))
print(s.rfind('p'))
# Out:
# 8
# 11
# -1

# %% [markdown]
# Syntax2: varname.rfind(substring, starting position)

# %%
s = 'abcdabcdabcd'
print(s.rfind('a',0))
print(s.rfind('d',12))
print(s.rfind('p',4))
print(s.rfind('d',-7))
# Out:
# 8
# -1
# -1
# 11

# %% [markdown]
# syntax3: varname.rfind(substring, starting position, ending position)

# %%
s = 'abcdabcdabcd'
print(s.rfind('a',0,3))
print(s.rfind('a',1,3))
print(s.rfind('b',2,4))
print(s.rfind('d',-3,len(s)))
print(s.rfind('c',-6,-2))
print(s.rfind('c',-6,-1))
# Out:
# 0
# -1
# -1
# 11
# 6
# 10

# %% [markdown]
# to get the last but one and last but two index through rfind function

# %%
s = 'abcdabcdabcd'
print(s.rfind('a'))
print(s.rfind('a',0,s.rfind('a')))# last but one
print(s.rfind('a',0,s.rfind('a',0,s.rfind('a'))))# last but two
print(s.rfind('a',0,s.rfind('a',0,s.rfind('a',0,s.rfind('a')))))
# Out:
# 8
# 4
# 0
# -1

# %% [markdown]
# 7. replace function:

# %% [markdown]
# 1. replace function chnages the old substring with the new substring in new memory location.
# 2. Existing memory location will not be change it will be constant or remain same.
# 3. replace function returns string(with new memory location)
# 4. generaaly replace function creates a new memory location.

# %% [markdown]
# Syntax1: varnname.replace(old substring, new ubstring)

# %%
s = 'abcdacd'
print(s.replace('a','A'))
print(s.replace('D','d'))
# print(s.replace()) it will raise error bcoz replace function takes atleast 2 argument
print(s.replace('a',''))# this will delete that substring 
print(s.replace('y','a'))# if substr is no present it will leave it as it is
print(s.replace('bc','hell'))
# Out:
# AbcdAcd
# abcdacd
# bcdcd
# abcdacd
# ahelldacd

# %% [markdown]
# Syntax2: varname.replace(old substr, new substr, count) Here count refers to how many times you want to replace

# %%
s = 'abcdacD'
print(s.replace('a','A',1))
print(s.replace('a','A',2))
print(s.replace('a','A',10)) # maxm times replace will happen and rest will be ignored
print(s.replace('a','',1))
print(s.replace('D','',3))
# Out:
# AbcdacD
# AbcdAcD
# AbcdAcD
# bcdacD
# abcdac

# %% [markdown]
# The prrof of that replace function creates a new memory location and the original memory locations not gets afftected

# %%
d = 'ravi'
z = id(print(d.replace('y','A')))
w = id(d)
print(z is w)
# Out:
# ravi
# False

# %%
m = 'biswa'
n = id(m.replace('z','k'))
l = id(m)
print(n is l)
# Out:
# False

# %% [markdown]
# 8. UPPER FUNCTION:

# %% [markdown]
# 1. It converts lowercase character to upper case character
# 2. upper function returns string

# %% [markdown]
# Syntax: varname.upper()

# %%
# practice file
s = 'abCD'
print(s.upper())
a = 'a3#w'
print(a.upper())
# updated
# Out:
# ABCD
# A3#W

# %% [markdown]
# 9. lower function:

# %% [markdown]
# 1. lower function converts uppercase characters to lower case characters.
# 2. lower functions= return string in new memory location.

# %% [markdown]
# Syntax: varname.lower()

# %%
s = 'ABcd'
print(s.lower())
d = 'aBCD2@V'
print(s.lower())
# Out:
# abcd
# abcd

# %% [markdown]
# 10. swapcase function:

# %% [markdown]
# Syntax: varname.swapcase()

# %% [markdown]
# 1. swapcase function converts lowercase characters to uppercase character and vice-versa
# 2. swap case function return string in new memory location.

# %%
s = 'ABCDsdh%we'
print(s.swapcase())
# Out:
# abcdSDH%WE

# %% [markdown]
# 11 title function:

# %% [markdown]
# Syntax: varname.title()

# %% [markdown]
# 1. title functiuon converts the first character of every word into upper case and remaning into lower case.
# 2. title function returns string in new memory location.

# %%
s = 'hello my world'
print(s.title())
# Out:
# Hello My World

# %% [markdown]
# 12 capitalize function:

# %% [markdown]
# Syntax: varname.capitalize()

# %% [markdown]
# 1. capitalize function converts the first character of the string into upper case and remaning into lowercase.
# 2. capitalize function return string in new memory location.

# %%
s = 'hello my world'
print(s.capitalize())
# Out:
# Hello my world

# %% [markdown]
# 13   isupper function:

# %% [markdown]
# 1. isupper function return true if string contains only uppercase characters otherwise false.
# 2. isuuper function returns boolean data

# %% [markdown]
# Syntax: s.isupper()

# %%
s = 'abc'
print(s.isupper())
print('ABC'.isupper())
# Out:
# False
# True

# %% [markdown]
# 14 islower function:

# %% [markdown]
# Syntax: varname.islower()

# %% [markdown]
# 1. islower function returns true if all the characters of string are in lowercase otherwise return false.
# 2. islower function returns boolean data.

# %%
s = 'lower'
print(s.islower())
print('Absd'.islower())
# Out:
# True
# False

# %% [markdown]
# 15 isdigit function:

# %% [markdown]
# Syntax: varname.isdigit()

# %% [markdown]
# 1. isdigit function returns true if string contains only numeric values. otherwise false.
# 2. this function returns boolean data.

# %%
s = '1234'
print(s.isdigit())
print('a23'.isdigit())
# Out:
# True
# False

# %% [markdown]
# 16. isalpha function:

# %% [markdown]
# Syntax: varname.isalpha()

# %% [markdown]
# 1. isalpha function return true if the string contains only alphabet otherwise returns false.
# 2. isalpha funtion returns boolean data.

# %%
x = 'abh2'
print(x.isalpha())
print('asd'.isalpha())
print('@as'.isalpha())
# Out:
# False
# True
# False

# %% [markdown]
# 17. isalnum function:

# %% [markdown]
# Syntax: varname.isalnum()

# %% [markdown]
# 1. isalnum function returns true if the string contains either numeric value or alphabet otherwise false.
# 2. isalnum function return boolean data.

# %%
s = '12'
print(s.isalnum())
print('sd'.isalnum())
print('@12s'.isalnum())
# Out:
# True
# True
# False

# %% [markdown]
# 18. strip function:

# %% [markdown]
# Syntax1: varname.strip() -> no argument(space)
#
# Syntax2: varname.stripn(substr)

# %% [markdown]
# 1. this function removes unwanted characters which are present at starting and ending of the string.
# 2. if argument is not given then space is the default substring.
# 3. strip function returns string in new memory location.

# %%
s = 'abcda'
print(s.strip('a'))
d = 'abcdfg'
print(d.strip('a'))
print(d.strip('g'))
x = ' abds '
print(x.strip())
k = ' ab fg nm d'
print(k.strip('d'))
k1 = 'abcbcabcddfgabc'
print(k1.strip('abc'))
# Out:
# bcd
# bcdfg
# abcdf
# abds
#  ab fg nm
# ddfg

# %% [markdown]
# 19. lstrip function:

# %% [markdown]
# Syntax: varname.lstrip()

# %% [markdown]
# 1. lstrip function only removes unwanted characters from the let of the substring or from the starting position.
# 2. lstrip function returns string in the new memory location.

# %%
s = 'abcdf'
print(s.lstrip('a'))
# Out:
# bcdf

# %% [markdown]
# 20. rstrip function:

# %% [markdown]
# Syntax: varname.rstrip()

# %% [markdown]
# 1. rstrip function removes unwanted characters from the ending part or from the right part of the subtring only.
# 2. rstrip function return string in new memory location.

# %%
s = 'abcda'
print(s.rstrip('a'))
# Out:
# abcd

# %% [markdown]
# List Built-in Function:

# %% [markdown]
# 1. append function:

# %% [markdown]
# Syntax: varname.append()
#
# Note: append function takes exactly one argument.

# %% [markdown]
# 1. append functioj can add only one element in existing memory location, at the ending of the list.
# 2. append function returns None

# %%
l = [1,2,34]
print(l.append())# this will give error bcoz append function can take exactly one argument.

# %%
l = [1,2,3]
print(l.append(4))
print(l)
print(l.append('Hello'))
print(l)
print(l.append([10,20,30]))
print(l)
print(l.append(3+4j))
print(l)
# Out:
# None
# [1, 2, 3, 4]
# None
# [1, 2, 3, 4, 'Hello']
# None
# [1, 2, 3, 4, 'Hello', [10, 20, 30]]
# None
# [1, 2, 3, 4, 'Hello', [10, 20, 30], (3+4j)]

# %% [markdown]
# 2. insert function:

# %% [markdown]
# Syntax: varname.insert(index position, value)

# %% [markdown]
# 1. insert function adds one element at required index position.
# 2. insert methgod returns None
# 3. if index position is out of range in positive index it will add in the last and if index position is out of range in negative index it will add in the last of the list.
# 4. insert functions takes 2 argument.

# %%
l = [1,2,3]
l.insert() # this will throw error bcoz insert expects 2 argument.

# %%
l = [1,'a',3]
print(l.insert(1,500))
print(l)
print(l.insert(0,'test'))
print(l)
print(l.insert(8,23))# since we has no 8th index it will add at the last
print(l)
print(l.insert(-2,200))
print(l)
k = [1,2,3]
print(k.insert(-5,4))
print(k)
# Out:
# None
# [1, 500, 'a', 3]
# None
# ['test', 1, 500, 'a', 3]
# None
# ['test', 1, 500, 'a', 3, 23]
# None
# ['test', 1, 500, 'a', 200, 3, 23]
# None
# [4, 1, 2, 3]

# %% [markdown]
# 3. extend function:

# %% [markdown]
# Syntax: varname.extend()

# %% [markdown]
# 1. extend funcion can add multiple elements at ending of the list.
# 2. extend function returns none
# 3. inside extend function only collection data types can be taken as arguments.
# 4. if we will take dictionary as an argument it will trake only the keys of that dictionary.
# 5. in tuple if we will pass single elment without giving comma it will take as its own data type

# %%
l = [1,2,3]
print(l.extend(234))# we can not give single valued data in extend function
# only iterable or collection or sequence typed data can be given

# %%
l = [3,'a',5]
print(l.extend('hello'))
print(l)
print(l.extend([1,2,3]))
print(l)
print(len(l))
# Out:
# None
# [3, 'a', 5, 'h', 'e', 'l', 'l', 'o']
# None
# [3, 'a', 5, 'h', 'e', 'l', 'l', 'o', 1, 2, 3]
# None
#
# 15

# %%
l = [1,2,3]
print(l.extend((True,2,'a')))
print(l)
k = [1,2,3]
print(k.extend('abcd'))
print(k)
j = [1,2,3]
print(j.extend(('abcd',)))
print(j)
# Out:
# None
# [1, 2, 3, True, 2, 'a']
# None
# [1, 2, 3, 'a', 'b', 'c', 'd']
# None
# [1, 2, 3, 'abcd']

# %%
l = [1,2,3]
print(l.extend({'b',False,-5,'A'}))
print(l)
l1 = [1,2,3]
print(l1.extend({'A':23,'B':[23,34]}))
print(l1)
# Out:
# None
# [1, 2, 3, 'b', False, 'A', -5]
# None
# [1, 2, 3, 'A', 'B']

# %%
l = [1,2,3]
print(l.extend(' '))
print(l)
# Out:
# None
# [1, 2, 3, ' ']

# %% [markdown]
# 4. remove function:

# %% [markdown]
# Syntax:varname.remove()

# %% [markdown]
# 1. This function removes the first occurrence of given element from the list.
# 2. If the given element is not present then it throws error(ValueError).
# 3. remove function returns None
# 4. remove function perform in the existing memory location after performing remove function the old list got vanished and new one gets created.

# %%
l = [1,2]
# print(l.remove()) This will throws error bcoz remove function takes one argument.

# %%
l = [1,2,3,4,2]
print(l.remove(2))
print(l)
k = [100,200,300,400]
#print(k.remove(500)) this will raise error
# Out:
# None
# [1, 3, 4, 2]

# %% [markdown]
# 5. pop function:

# %% [markdown]
# Syntax1: varname.pop(position)
#
# Syntax2: varname.pop() -> no argument (default is -1)

# %% [markdown]
# 1. pop function removes the element based on index position.
# 2. If index position is not given -1 is the default index position
# 3. pop function returns removed element.
# 4. We can not perform pop function in empty list
# 5. If we will pass any index which is not present then it will throws indexError

# %%
l = [1,2,3,4]
# print(l.pop(5)) it will throw index error

# %%
l = [1,2,3,4]
print(l.pop(1))
print(l)
print(l.pop())
# Out:
# 2
# [1, 3, 4]
# 4

# %% [markdown]
# 6. clear function:

# %% [markdown]
# Syntax: varname.clear() no argument

# %% [markdown]
# 1. clear function removes all elements from the list
# 2. remove funtion returns None

# %%
l = [1,2,3,4]
print(l.clear())
# Out:
# None

# %%
l = [1,2,3]
print(l.clear())
print(l)
# Out:
# None
# []

# %%
l = []
print(l.clear())
print(l)
# Out:
# None
# []

# %% [markdown]
# 7. reverse function:

# %% [markdown]
# Syntax: varname.reverse() -> no argument

# %% [markdown]
# 1. This function change sthe direction of the given elements.
# 2. reverse function updates the order in the existing memory location.
# 3. reverse function returns None

# %%
l = [1,'a',False,50]
print(l.reverse())
print(l)
# Out:
# None
# [50, False, 'a', 1]

# %%
l = []
print(l.reverse())
print()
# Out:
# None

# %%
l = [4]
print(l.reverse())
print(l)
# Out:
# None
# [4]

# %% [markdown]
# 8. sort function:

# %% [markdown]
# Syntax: varname.sort() -> for ascending order
#
# Syntax2: varname.sort(reverse=True) -> for descending order

# %%
s = [12,9,34,23,21,31]
print(s.sort())
print(s)
print(s.sort(reverse=True))
print(s)
# Out:
# None
# [9, 12, 21, 23, 31, 34]
# None
# [34, 31, 23, 21, 12, 9]

# %%
s = [12,-3,11,23,-32]
print(s.sort(reverse=False))# same as ascending order
print(s)
# Out:
# None
# [-32, -3, 11, 12, 23]

# %%
s = []
print(s.sort())
print(s)
# Out:
# None
# []

# %%
s = [4]
print(s.sort())
print(s)
# Out:
# None
# [4]

# %%
# if you are taking ascii value then take for all not for any single element it will throw error like belpow code
s = [12,'a',34,21]
print(s.sort())
print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 s = [12,'a',34,21]
# ----> 2 print(s.sort())
#       3 print()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %% [markdown]
# 9. copy function:

# %% [markdown]
# Syntax: Varname.copy() -> No sargument (This is shaloow copy)

# %% [markdown]
# 1. copy function creates the list in different memory locatio.
# 2. copy function returns list.

# %%
l = [4,1,8,5]
print(l.copy())
# Out:
# [4, 1, 8, 5]

# %%
# the memory location for both the variable are different
l = [1,2,3,4]
d = l.copy()
print(id(l))
print(id(d))
print(id(l) is id(d))
# Out:
# 4396660160
# 4396583680
# False

# %%
l = {'A':23,'B':[23,34]}
print(l.copy())
# Out:
# {'A': 23, 'B': [23, 34]}

# %% [markdown]
# 12. join function:

# %% [markdown]
# Syntax: str.join(varname) -> list conatins only striong

# %% [markdown]
# 1. this function combines the list of strings with the help of joining characters.
# 2. this function returns in new memory location.

# %%
l = ['h','e','a','v']
print('@'.join(l))
# Out:
# h@e@a@v

# %%
# All the elemenst data type should be same
l = [1,2,3,4,'a']
print('-'.join(l))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 l = [1,2,3,4,'a']
# ----> 2 print('-'.join(l))
#
# TypeError: sequence item 0: expected str instance, int found

# %%
# Inside the list every element should be string then only join possible
l = ['1','2','3','4']
print('-'.join(l))
# Out:
# 1-2-3-4

# %%
l = ['a','1','p','3']
print(''.join(l))
# Out:
# a1p3

# %% [markdown]
# Built-in function for tuple:

# %% [markdown]
# 1. count function:

# %% [markdown]
# Syntax: varname.count(element)

# %% [markdown]
# 1. count function in tuple takes exactly one argument
# 2. count function returns the  total occureence of the element
# 3. if element is not present in the given tupel then count function returns 0

# %%
s = (1,2,3,4,1)
print(s.count(1))
print(s.count(-1))
print(s.count(3))
# Out:
# 2
# 0
# 1

# %%
n = ('q',12,True,5.0,'q',1)
print(n.count('q'))
print(n.count(12))
print(n.count(True))
print(n.count(False))
# Out:
# 2
# 1
# 2
# 0

# %% [markdown]
# 2. index function:

# %% [markdown]
# Syntax1: varname.index(element)
#
# Syntax2: varname.index(element, starting Position)
#
# Syntax3: varname.index(element, starting Position, Ending Position)

# %% [markdown]
# 1. index function returns the first occurrence of the given element.
# 2. If element is not present in the given tuple index function throws value error.
# 3. index function returns integer.
# 4. tuple does not support rindex function and find function.

# %%
d = (1,2,'q',9.0,3+4j,1,4.3,'q',9)
print(d.index(2))
print(d.index(1,2))
print(d.index(1,-4))
print(d.index('q',3,8))
print(d.index(4.3,-4,-1))
# Out:
# 1
# 5
# 5
# 7
# 6

# %%
d = (1,2,4.0,'q',3,2,'a')
print(d.index(4.0,2,5))
# Out:
# 2

# %%
# This wil raise error because element is not present in the tuple
d = (1,2,3)
print(d.index(50))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 2
#       1 d = (1,2,3)
# ----> 2 print(d.index(50))
#
# ValueError: tuple.index(x): x not in tuple

# %%
d = (1,2,4.0,'r',False,9j)
print(d.index(1,2,5))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 d = (1,2,4.0,'r',False,9j)
# ----> 2 print(d.index(1,2,5))
#
# ValueError: tuple.index(x): x not in tuple

# %% [markdown]
# To get the 2nd occurrence of an element:

# %% [markdown]
# Syntax: varname.index(element, starting position of that elemnt+1)

# %%
d = (1,2,3,1,3,4,5,1)
print(d.index(1)) # first occurrence
print(d.index(1,d.index(1)+1)) # 2nd occurrence
print(d.index(1, d.index(1,d.index(1)+1)+1)) # 3rd occurrence
# Out:
# 0
# 3
# 7

# %% [markdown]
# Built-in functions for set:

# %% [markdown]
# 1. add function:

# %% [markdown]
# Syntax: varname.add(key) -> The key must be single valued and unhashable typed data

# %% [markdown]
# 1. add function allows exactly one argument and the element is added in random place in the set(bcoz set is unordered).
# 2. add funtion returns None

# %%
s = {4,'a',1}
print(s.add(4))
print(s)
print(s.add('-3'))
print(s)
# Out:
# None
# {1, 'a', 4}
# None
# {1, 'a', 4, '-3'}

# %%
# this will throw error of unhashable
s = {1,2,3}
print(s.add([23,34]))
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 s = {1,2,3}
# ----> 2 print(s.add([23,34]))
#       3 print(s)
#
# TypeError: unhashable type: 'list'

# %%
s = {1,'e',3}
print(s.add((1,2,3)))
print(s)
# Out:
# None
# {1, 3, 'e', (1, 2, 3)}

# %% [markdown]
# 2. update function:

# %% [markdown]
# Syntax1: varname.update() -> No argument
#
# Syntax2: varname.update(collection data type)
#
# syntax3: varname.update(cdt1, cdt2,cdt3,  ) -> cdt means collection data types

# %% [markdown]
# 1. update function can add multiple keys at a random place in existiong memory location of set.
# 2. inside everry collection data type give only immutable data.
# 3. update function returns None.

# %%
s = {1,'a',2}
print(s.update())
print(s)
# Out:
# None
# {'a', 1, 2}

# %%
# This will raise error bco only immutable data and collection data type are aloowed
s = {1,'a',3}
print(s.update(34))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 3
#       1 # This will raise error bco only immutable data and collection data type are aloowed
#       2 s = {1,'a',3}
# ----> 3 print(s.update(34))
#
# TypeError: 'int' object is not iterable

# %%
s = {1,2,3}
print(s.update('abcd'))
print(s)
# Out:
# None
# {1, 2, 3, 'd', 'c', 'b', 'a'}

# %%
# thsi will raise error all the elements should follow the rule
s = {1,'a',3}
print(s.update('a','Abc',30))
print(s)

# %%
s = {1,'t',3.0,'44'}
print(s.update([44,'3.0',1]))
print(s)
# Out:
# None
# {1, 3.0, '44', 44, '3.0', 't'}

# %%
# this will riase error bcoz inside list all the elements should be unhashable
s = {1,2,3}
print(s.update([[12],33,44]))
print(s)

# %%
s = {1,'bye','hello','a'}
print(s.update('hii',[11,22,33]))
print(s)
# Out:
# None
# {1, 33, 'hello', 'i', 'bye', 11, 'h', 22, 'a'}

# %%
s = {1,2,3}
print(s.update(('hii',)))
print(s)
# Out:
# None
# {'hii', 1, 2, 3}

# %%
s = {1,2,3}
print(s.update('hello'))
print(s)
# Out:
# None
# {1, 2, 3, 'e', 'o', 'h', 'l'}

# %%
s = {1,2,3,4,'s'}
print(s.update([11,22,33],(66,77,88)))
print(s)
# Out:
# None
# {1, 2, 3, 4, 66, 11, 77, 22, 's', 88, 33}

# %%
# In dictionary it will take only the keys
s = {1,2,3,4}
print(s.update({'a':23,'b':[23,34]}))
print(s)
# Out:
# None
# {1, 2, 3, 4, 'b', 'a'}

# %%
s = {1,2,3}
print(s.update([11,22]))
print(s)
# Out:
# None
# {1, 2, 3, 11, 22}

# %%
s = {1,2,3}
print(s.update([11,22],(33,44),'mno'))
print(s)
# Out:
# None
# {1, 2, 3, 33, 'o', 11, 44, 'm', 'n', 22}

# %%
nums = [1,2,4,5]
n = len(nums)+1
total_sum = n*(n+1)//2
arr_sum = 0
for num in nums:
    arr_sum+=num
print(arr_sum)
print(total_sum-arr_sum)
# Out:
# 12
# 3

# %%
num = [10, 11, 12, 14, 15]

length = len(num)
start = num[0]
end = num[length - 1]

n = end - start + 1

total_sum = (start + end) * n // 2

curr_sum = 0

for x in num:
    curr_sum += x

number = total_sum - curr_sum

print(number)
# Out:
# 13

# %%
s = {1,2}
print(s.update('ab','cd'))
print(s)
# Out:
# None
# {1, 2, 'd', 'c', 'b', 'a'}

# %% [markdown]
# 3. remove function:

# %% [markdown]
# Syntax: varname.remove() -> only one argument(only one argument/key)

# %% [markdown]
# 1. remove function removes one key from a set.
# 2. If the given key is not present then remove function raises keyerror.
# 3. remove function returns None.

# %%
s = {1,2,(20,10)}
print(s.remove((20,10)))
print(s)
# Out:
# None
# {1, 2}

# %%
s = {1,2,'r',5}
print(s.remove()) # exactly one argument should be given inside remove function
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 s = {1,2,'r',5}
# ----> 2 print(s.remove())
#
# TypeError: set.remove() takes exactly one argument (0 given)

# %%
s = {1,2,3,4}
print(s.remove(20))# it will raise key error

# %%
s = {1,2,3,4}
print(s.remove(3))
print(s)
# Out:
# None
# {1, 2, 4}

# %% [markdown]
# 4. pop function:

# %% [markdown]
# Syntax: varname.pop() -> no argument

# %% [markdown]
# 1. pop function removes random element from a set.
# 2. pop function returns the removed element from the set.
# After removing all the keys from a set an empty set will be there only (set()).

# %%
s = {1,2,3,(20,30)}
print(s.pop())
print(s.pop())
print(s.pop())
print(s.pop())
# Out:
# 1
# 2
# 3
# (20, 30)

# %%
s = {1,'abc',2,3,(20,30)}
print(s.pop())
print(s.pop())
# Out:
# 1
# 2

# %% [markdown]
# 5. discard function:

# %% [markdown]
# Syntax: varname.discard() -> only one argument(key)

# %% [markdown]
# 1. discard function removes one key from a set.
# 2. If the given key is not present in that set discard function will not perform any operation(returns None).
# 3. discard function returns None.
# 4. discrad function only takes one argument.

# %%
s = {1,2,3,(34,'q')}
print(s.discard(9))
print(s)
print(s.discard('q'))
print(s)
print(s.discard((34)))
print(s)
print(s.discard((34,'q')))
print(s)
# Out:
# None
# {(34, 'q'), 1, 2, 3}
# None
# {(34, 'q'), 1, 2, 3}
# None
# {(34, 'q'), 1, 2, 3}
# None
# {1, 2, 3}

# %% [markdown]
# 6. clear function:

# %% [markdown]
# Syntax: varname.clear() -> no argument

# %% [markdown]
# 1. clear function removes all the keys present in that set.
# 2. clear function returns None.
# 3. clear function does not take any argument.

# %%
s = {1,2,3}
print(s.clear())
print(s)
# Out:
# None
# set()

# %% [markdown]
# 7. union function:

# %% [markdown]
# Syntax: var1.union(var2)

# %% [markdown]
# 1. union function combines all the elemenst from two sets or more than two sets.
# 2. union function returns a new result set in new memory location.

# %%
s1 = {1,2,3,'t'}
s2 = {3,4,'t','y'}
print(s1.union(s2))
print(s1)
print(s2)
print(s1.union(s1))
print(s2.union(s2))
print(s1.union())
# Out:
# {1, 2, 3, 'y', 't', 4}
# {1, 2, 3, 't'}
# {'y', 3, 4, 't'}
# {1, 2, 3, 't'}
# {'y', 3, 4, 't'}
# {1, 2, 3, 't'}

# %%
s1 = {1,2,3}
s2 = {2,3,4}
s3 = {3,4,5}
print(s1.union(s2).union(s3))
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# 8. intersection function:

# %% [markdown]
# Syntax: var1.intersection(var1)

# %% [markdown]
# 1. intersection function takes only matching keys from both sets.
# 2. it returns a new result set in new memory location.

# %%
s1 = {1,2,3,4,(23,'r')}
s2 = {(23,'r'),4,'p'}
print(s1.intersection(s2))
print(s2.intersection(s1))
print(s1.intersection(s1))
print(s2.intersection(s2))
print(s1)
print(s2)
# Out:
# {4, (23, 'r')}
# {4, (23, 'r')}
# {1, 2, 3, 4, (23, 'r')}
# {'p', 4, (23, 'r')}
# {1, 2, 3, 4, (23, 'r')}
# {'p', 4, (23, 'r')}

# %%
s1 = {1,2,3,4,5}
s2 = {3,4,5,6,7}
s3 = {4,5,6,8,9}
print(s1.intersection(s2).intersection(s3))
# Out:
# {4, 5}

# %% [markdown]
# 9. difference function:

# %% [markdown]
# Syntax: var1.difference(var2)

# %% [markdown]
# 1. difference function removes the matching keys and returns a result set in new memory location.

# %%
s = {1,2,3,4}
s2 = {3,5,6,7}
print(s1.difference(s2))
print(s2.difference(s1))
print(s1.difference(s1))
print(s2.difference(s2))
print(s1)
print(s2)
# Out:
# {1, 2, 4}
# {6, 7}
# set()
# set()
# {1, 2, 3, 4, 5}
# {3, 5, 6, 7}

# %%
s1 = {1,2,3,4,5}
s2 = {3,4,5,6,7}
s3 = {4,5,6,7,8}
print(s1.difference(s2).difference(s3))
# Out:
# {1, 2}

# %% [markdown]
# 10. copy function:

# %% [markdown]
# Syntax: varname.copy() -> no argument

# %% [markdown]
# 1. It creates new memory location.
# 2. it returns set.
# 3. It creates the set in different memory location(new memory location).

# %%
s = {1,2,3,4,(2,3,'t'),'tuple'}
dup = s.copy()
print(dup)
print(s)
print(s is dup)
# Out:
# {1, 2, 3, 4, (2, 3, 't'), 'tuple'}
# {1, 2, 3, 4, (2, 3, 't'), 'tuple'}
# False

# %% [markdown]
# 11. difference_update function:

# %% [markdown]
# Syntax: var1.difference_update(var2)

# %% [markdown]
# 1. difference update funtion removes the common elements from the given set and updates the set to the given memory location.
# 2. this function returns None.
# 3. this function works in the same memory location.

# %%
s = {1,2,3,4,('er',45)}
s1 = {4,3,2}
print(s.difference_update(s1))
print(s)
print(s1)
# Out:
# None
# {1, ('er', 45)}
# {2, 3, 4}

# %%
s = {1,2,3,4,('er',45)}
s1 = {4,3,2}
print(s1.difference_update(s))
print(s)
print(s1)
# Out:
# None
# {1, 2, 3, 4, ('er', 45)}
# set()

# %% [markdown]
# 12. intersection_update fuynction:

# %% [markdown]
# Syntax: var1.intersection_update(var2)

# %% [markdown]
# 1. intersection_update function removes all the key with the matching keys.
# 2. this unction returns None.
# 3. This function works in the same memory location.

# %%
s = {1,2,3,4,('er',45)}
s1 = {4,3,2,'p','w'}
print(s.intersection_update(s1))
print(s)
print(s1)
# Out:
# None
# {2, 3, 4}
# {'p', 2, 3, 4, 'w'}

# %%
s = {1,2,3,4,('er',45)}
s1 = {4,3,2,'p','w'}
print(s1.intersection_update(s))
print(s)
print(s1)
s.
# Out:
# None
# {1, 2, 3, 4, ('er', 45)}
# {2, 3, 4}

# %%
s = {1,2,3,4}
s1 = {2,3,4,5}
s2 = {3,4,5,6}
print(s.intersection_update(s1).intersection_update(s2))# this gives error bcoz of first result we will get as None so with None we can not do extra operations
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 4
#       2 s1 = {2,3,4,5}
#       3 s2 = {3,4,5,6}
# ----> 4 print(s.intersection_update(s1).intersection_update(s2))# this gives error bcoz of first result we will get as None so with None we can not do extra operations
#
# AttributeError: 'NoneType' object has no attribute 'intersection_update'

# %% [markdown]
# 13. isdisjoint function:

# %% [markdown]
# Syntax: var1.isdisjoint(var2)

# %% [markdown]
# 1. isdisjoint function returns True if no common elements present in multiple set. otherwise returns False.
# 2. isdisjoint function returns Boolean data.

# %%
s1 = {1,2,3}
s2 = {True,5,7}
print(s1.isdisjoint(s2))
# Out:
# False

# %%
s1 = {1,2,3}
s2 = set()
print(s1.isdisjoint(s2))
# Out:
# True

# %% [markdown]
# 14. issubset function:

# %% [markdown]
# Syntax: var1.issubset(var2)

# %% [markdown]
# 1. issubset function returns True if the elements from set1 is present in set2, otherwise False.
# 2. issubset function returns Boolean data.

# %%
s1 = set()
s2 = {1,2,3}
print(s1.issubset(s2))
# Out:
# True

# %%
s1 = {1,2,3,(1,2,'a')}
s2 = {1,2,3,4,5,(1,2,'a')}
print(s1.issubset(s2))
# Out:
# True

# %% [markdown]
# 15. issuperset function:

# %% [markdown]
# Syntax: var1.issuperset(var2)

# %% [markdown]
# 1. issuperset function returns true if all the elemenst of set1 is contained by set2 , otherwise false.
# 2. issuperset function returns Boolean data.

# %%
s1 = {1,2,3}
s2 = {1,2,3}
print(s1.issubset(s2))
print(s2.issuperset(s1))
# Out:
# True
# True

# %%
s1 = set()
s2 = {1,2,3}
print(s2.issuperset(s1))
# Out:
# True

# %%
s1 = set()
s2 = set()
print(s1.issuperset(s2))
# Out:
# True

# %%
s1 = {1,2,3}
print(s1.issubset(s1))
print(s1.issuperset(s1))
# Out:
# True
# True

# %% [markdown]
# 16. symmetric_difference function:

# %% [markdown]
# Syntax: var1.symmetric_difference(var2)

# %% [markdown]
# 1. This function returns every element from multiple set except common elements.
# 2. this function returns set in new memory location.

# %%
s1 = {3,1,500}
s2 = {5,'a',3,2,1}
print(s1.symmetric_difference(s2))
# Out:
# {2, 500, 5, 'a'}
# {1, 3, 500}

# %%
s1 = {1,2,3}
s2 = {1,2,3}
print(s1.symmetric_difference(s2))
# Out:
# set()

# %%
s1 = {1,2,3}
s2 = set()
print(s1.symmetric_difference(s2))
# Out:
# {1, 2, 3}

# %% [markdown]
# 17. symmetric_difference_update function:

# %% [markdown]
# Syntax: var1.symmetric_difference_update(var2)

# %% [markdown]
# 1. This function returns every element except common elements from multiple set and replace the original set with the new result.
# 2. This function returns None
# 3. This perform in the same memory location.
# 4. the new result set replaces the original set.

# %%
s1 = {1,2,3,4,5}
s2 = {5,6,7,3,9}
print(s1.symmetric_difference_update(s2))
print(s1)
print(s2)
print(s2.symmetric_difference_update(s1))
print(s1)
print(s2)
# Out:
# None
# {1, 2, 4, 6, 7, 9}
# {3, 5, 6, 7, 9}
# None
# {1, 2, 4, 6, 7, 9}
# {1, 2, 3, 4, 5}

# %%
s1 = set()
s2 = set()
print(s1.symmetric_difference_update(s2))
print(s1)
print(s2)
# Out:
# None
# set()
# set()

# %%
s1 = {1,2,3}
s2 = {1,2,3}
print(s1.symmetric_difference_update(s2))
print(s1)
print(s2)
# Out:
# None
# set()
# {1, 2, 3}

# %% [markdown]
# Built-in functions of Dictionary:

# %% [markdown]
# 1. To add new key value or to change the value of an existing Key:

# %% [markdown]
# Syntax: var[key] = value

# %% [markdown]
# 1. we can only pass single valued data and immutable data as the key and the value can be of any type

# %%
d = {'a':40,'b':20}
d['a']=60
print(d)
d[300]=[23,3,4]
print(d)
# Out:
# {'a': 60, 'b': 20}
# {'a': 60, 'b': 20, 300: [23, 3, 4]}

# %%
d = {'a':23,'b':34}
d[[12]]=50# this will raise error bcoz of list
# so we can pass tuple ,string,int,float,boolean,complex,None as keys

# %% [markdown]
# 2. update function:

# %% [markdown]
# Syntax1: Varname.update() -> no argument
#
# Syntax2: Varname.update(collection data type excluding string(list,tuple,set,dictionary) only allowed)

# %% [markdown]
# 1. update function can add multiple key-values to existing memory location of dictionary.
# 2. The length of every element in collection type of data should be 2.
# 3. update function returns None.

# %%
a = {'a':40,'b':20}
print(a.update())
# Out:
# None

# %%
d = {'a':20,'b':45}
print(d.update[34])# since the key is inside a mutable type data it will raise error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 d = {'a':20,'b':45}
# ----> 2 print(d.update[34])# since the key is inside a mutable type data it will raise error
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
d = {'a':20,'b':45}
print(d.update(['mn',[55,66],(22,33)]))
print(d)
# Out:
# None
# {'a': 20, 'b': 45, 'm': 'n', 55: 66, 22: 33}

# %%
d = {'a':20,'b':45}
print(d.update(['mno',[55,66],(22,33)]))# This will raise error bcoz every element length must have 2

# %%
d = {'a':20,'b':45}
print(d.update(('bc',[11,22],'pq',(55,66))))
print(d)
# Out:
# None
# {'a': 20, 'b': 'c', 11: 22, 'p': 'q', 55: 66}

# %% [markdown]
# 1. update function adds the keys and values one by one
# 2. ex: if while adding the first key value got added and the second one raises error so in that case the first one will be added and from 2nd onwards this will not execute.

# %%
d = {'a':20,'b':45}
print(d.update(['wq',34,(34,56)]))
print(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 d = {'a':20,'b':45}
# ----> 2 print(d.update(['wq',34,(34,56)]))
#       3 print(d)
#
# TypeError: cannot convert dictionary update sequence element #1 to a sequence

# %%
# here we got 'qw' as key value paire after this nothing happened
print(d)
# Out:
# {'a': 20, 'b': 45, 'w': 'q'}

# %%
d = {'a':20,'b':45}
print(d.update('mn'))# this is a string but we need every element length as 2 so for that reason it will raise error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 d = {'a':20,'b':45}
# ----> 2 print(d.update('mn'))# this is a string but we need every element length as 2 so for that reason it will raise error
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required

# %%
d = {'a':20,'b':45}
print(d.update('mnop'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 2
#       1 d = {'a':20,'b':45}
# ----> 2 print(d.update('mnop'))
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required

# %%
d = {'a':20,'b':45}
print(d.update(('mn',)))
print(d)
# Out:
# None
# {'a': 20, 'b': 45, 'm': 'n'}

# %% [markdown]
# 3. pop function:

# %% [markdown]
# Syntax: varname.pop()

# %% [markdown]
# 1. This function removes one key value pair from dictionary.
# 2. If key is not present pop functyion returns default value(if default value is not given then pop function returns error).
# 3. pop function takes atleast 1 argument and atmost 2 argument.
# 4. The default value can be of any data type.

# %%
d = {'a':50,'b':60}
print(d.pop())# this will raise error atleast one argument should be there

# %%
d = {'a':50,'b':60}
print(d.pop('a'))
print(d)
# Out:
# 50
# {'b': 60}

# %%
d = {'a':50,'b':60}
print(d.pop('i',500))
print(d)
# Out:
# 500
# {'a': 50, 'b': 60}

# %%
d = {'a':30,'b':40,'c':70}
print(d.pop('a','b'))
print(d)
# Out:
# 30
# {'b': 40, 'c': 70}

# %%
d = {'a':50,'b':60}
print(d.pop('a','b'))
print(d)# here 'b' is trated as default value not as a key
# Out:
# 50
# {'b': 60}

# %% [markdown]
# 4. popitem function:

# %% [markdown]
# Syntax: varname.popitem()

# %% [markdown]
# 1. popitem function removes last key-value pair from the dictionary.
# 2. popitem returns the removed key-value pair in the form of tuple.
# 3. To perform popitem function dictionary may have atleast one key-value pair.
# 4. popitem function removes key-value pair from the last of the dictionary(bcoz dictionary is ordered).
# 5. popitem function does not take any arguments.

# %%
d = {'a':50,'b':40,'c':100}
print(d.popitem())
print(d)
print(d.popitem())
print(d)
# Out:
# ('c', 100)
# {'a': 50, 'b': 40}
# ('b', 40)
# {'a': 50}

# %%
d = {}
print(d.popitem())# this will raise error bcoz the dictionary is empty atleast one key-value pair should be there

# %% [markdown]
# 5. clear function:

# %% [markdown]
# Syntax: varname.clear()

# %% [markdown]
# 1. clear function can be performed only on mutable data types.
# 2. clear function removes all the key-values from the dictionary.
# 3. It returns None.
# 4. clear function does not takes any arguments.

# %%
d = {}
print(d.clear())
# Out:
# None

# %%
d = {'a':50,'b':40,'c':100}
print(d.clear())
# Out:
# None

# %% [markdown]
# 6. keys function:

# %% [markdown]
# Syntax: varname.keys()

# %% [markdown]
# 1. keys function returns all the keys from the dictionary.
# 2. keys function does not take any argument.
# 3. keys function returns the keys in the form of list.

# %%
d = {'a':50,'b':40,'c':100}
print(d.keys())
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
d = {}
print(d.keys())
# Out:
# dict_keys([])

# %% [markdown]
# 7. values function:

# %% [markdown]
# Syntax: varname.values()

# %% [markdown]
# 1. values function returns all the values from the dictionary.
# 2. values function does not take any argument.
# 3. values function returns values from the dictionary in the form of list.

# %%
d = {'a':50,'b':40,'c':100}
print(d.values())
# Out:
# dict_values([50, 40, 100])

# %%
d = {}
print(d.values())
# Out:
# dict_values([])

# %% [markdown]
# 8. items function:

# %% [markdown]
# Syntax: varname.items()

# %% [markdown]
# 1. items function returns all the key-value pair from the dictionary.
# 2. items functioon does not take any argument.
# 3. items function returns the keys-values in tuple then all the tuple are returns in the form of list.

# %%
d = {'a':50,'b':40,'c':100}
print(d.items())
# Out:
# dict_items([('a', 50), ('b', 40), ('c', 100)])

# %%
d = {}
print(d.items())
# Out:
# dict_items([])

# %%
d = {}
print(d.keys())
print(d.values())
print(d.items())
# Out:
# dict_keys([])
# dict_values([])
# dict_items([])

# %%
d = {'a':100,'b':'23','c':[12,2,3]}
print(d.get('b'))
print(type(d.get('b')))
print(d.get('c'))
# Out:
# 23
# <class 'str'>
# [12, 2, 3]

# %%
d = {}
print(d.get(''))
# Out:
# None

# %%
d = {'a':400,'b':100,'c':800}
print(d.setdefault('b'))
print(d)
# Out:
# 100
# {'a': 400, 'b': 100, 'c': 800}

# %%
d = {'a':23,'b':100}
print(d.get('a'))
print(d.get('d'))
print(d.get('d',[12,45]))
# Out:
# 23
# None
# [12, 45]

# %%
d = {'a':23,'b':100}
print(d.setdefault('c',400))
print(d)
print(d.setdefault('d'))
print(d)
print(d.setdefault('a',[12,93]))
print(d)
# Out:
# 400
# {'a': 23, 'b': 100, 'c': 400}
# None
# {'a': 23, 'b': 100, 'c': 400, 'd': None}
# 23
# {'a': 23, 'b': 100, 'c': 400, 'd': None}

# %%
d = {}
print(d.fromkeys(['a','b','c','d'],100))
print(d)
# Out:
# {'a': 100, 'b': 100, 'c': 100, 'd': 100}
# {}

# %%
d = {}
print(d.fromkeys('abcd',100))
print(d.fromkeys({'a':10,'b':20}))
print(d.fromkeys({'a':10,'b':20},100))
print(d.fromkeys({'a':10,'b':10},200))
print(d.fromkeys({2:[1,2,3],(12,34):{1,2,3}},100))
print(d.fromkeys({'a':100,'b':345},{'a':100,'b':90}))
# Out:
# {'a': 100, 'b': 100, 'c': 100, 'd': 100}
# {'a': None, 'b': None}
# {'a': 100, 'b': 100}
# {'a': 200, 'b': 200}
# {2: 100, (12, 34): 100}
# {'a': {'a': 100, 'b': 90}, 'b': {'a': 100, 'b': 90}}
